# %%
# 1. Area Chart
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv("/Users/shivammarkanday/Library/CloudStorage/OneDrive-AdaniUniversity/OneDrive College/SEM 6 (2026)/DV/Jupyter Notebook/Lab4/Datasets/Iris.csv")

avg_petal_length = data.groupby("Species")["PetalLengthCm"].mean()

species = avg_petal_length.index
values = avg_petal_length.values

plt.stackplot(species,values,labels=species)

plt.title("Average Petal Length by Species")
plt.xlabel("Species")
plt.ylabel("Average Petal Length (cm)")


plt.grid(True,which="major")
plt.minorticks_on()
plt.grid(True, which="minor", linestyle="--", alpha=0.5)

plt.legend(
    title="Species",
    loc = "lower right",
    fontsize = 12
)

plt.show()

# %%
# 2. Bubble Chart
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

data = pd.read_csv("/Users/shivammarkanday/Library/CloudStorage/OneDrive-AdaniUniversity/OneDrive College/SEM 6 (2026)/DV/Jupyter Notebook/Lab4/Datasets/Iris.csv")

species_list = data["Species"].unique()

for species in species_list:
  subset = data[data["Species"] == species]

  plt.scatter(
      subset['SepalLengthCm'],
      subset['SepalWidthCm'],
      s = subset['PetalLengthCm'] *30,
      alpha = 0.4,
      label = species
  )

plt.title("Iris Flower Features")

plt.legend(
    title = "Species"
)

plt.plot()
# Out:
# []

# %%
# Heat Map
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv("/Users/shivammarkanday/Library/CloudStorage/OneDrive-AdaniUniversity/OneDrive College/SEM 6 (2026)/DV/Jupyter Notebook/Lab4/Datasets/Iris.csv")

numeric_data = data.select_dtypes(["number"])

corr_matrix = numeric_data.corr()

plt.figure(figsize=(8, 6))
sns.heatmap(
    corr_matrix,
    annot=True,        # Show correlation values
    cmap="coolwarm",   # Color map for better contrast
    linewidths=0.5
)

plt.title("Heatmap of Iris Features")

plt.show()

# %%
# 4. Box Plot
import pandas as pd
import matplotlib.pyplot as plt

data = pd.read_csv("/Users/shivammarkanday/Library/CloudStorage/OneDrive-AdaniUniversity/OneDrive College/SEM 6 (2026)/DV/Jupyter Notebook/Lab4/Datasets/Iris.csv")

species_list = data["Species"].unique()

petal_length_data= []

for species in species_list:
  petal_length_data.append(
      data[data["Species"] == species]["PetalLengthCm"]
  )

plt.boxplot(
    petal_length_data,
    labels=species_list,
    patch_artist=True,
    showfliers=True,
    flierprops=dict(          
        marker='o',
        markerfacecolor='red',
        markersize=6,
        linestyle='--'
    )
)


plt.title("Petal Length Distribution by Species")
plt.xlabel("Species")
plt.ylabel("Petal length (cm)")

plt.grid(axis="y", linestyle="--", alpha=0.6)

plt.show()
# Out:
# /var/folders/n5/cp_xjkmj02l8hcmqll27y61m0000gn/T/ipykernel_37472/4153607866.py:16: MatplotlibDeprecationWarning: The 'labels' parameter of boxplot() has been renamed 'tick_labels' since Matplotlib 3.9; support for the old name will be dropped in 3.11.
#   plt.boxplot(

# %%
#violin plot 
from matplotlib.legend import Legend
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns


data = pd.read_csv("/Users/shivammarkanday/Library/CloudStorage/OneDrive-AdaniUniversity/OneDrive College/SEM 6 (2026)/DV/Jupyter Notebook/Lab4/Datasets/Iris.csv")

sns.violinplot(
    x="Species",
    y="PetalWidthCm",
    data=data,
    hue="Species",
    palette="viridis",
    legend=False

)


plt.title("Petal Width Distribution by Species")
plt.xlabel("Species")
plt.ylabel("Petal Width (cm)")

plt.grid(axis="y", linestyle="--", alpha=0.6)


plt.show()
